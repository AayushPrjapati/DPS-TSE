# %% [markdown]
# # USEF-TSE & ArrayDPS: End-to-End Inference & Showcase Rebuilder
#
# This Google Colab notebook automates the target speaker extraction pipeline for all 5 cases. It performs:
# 1. **Phase 1 (USEF-TSE)**: Discriminative speaker extraction on 8kHz audio.
# 2. **Phase 2 (ArrayDPS)**: Generative refinement using joint mixture guidance in 65,536-sample chunks to prevent OOM/GPU crashes on long sequences.
# 3. **Spectrogram Generation**: Automatically generates borderless, flat `'viridis'` spectrogram PNG files.
# 4. **GitHub Push**: Commits and pushes the updated audio files, spectrograms, and site layout directly back to your GitHub Pages repository.

# %% [markdown]
# ## Step 1: Install Dependencies
# Install the required libraries for both Phase 1 and Phase 2 models.

# %%
# Install dependencies (runs in under 1 minute)
# !pip install dotmap hyperpyyaml soxr pystoi pesq transformers huggingface_hub soundfile torchaudio matplotlib numpy

# %% [markdown]
# ## Step 2: Run End-to-End Inference
# Run the automated script `run_inference_all_cases.py`. This script will load the CUDA GPU automatically, run the double-stage inference on all 5 cases, and update `docs/audio` and `docs/images`.

# %%
# Run inference on all cases and regenerate the viridis spectrograms
# !python run_inference_all_cases.py

# %% [markdown]
# ## Step 3: Push Updates to GitHub
# Enter your GitHub details and Personal Access Token (PAT) below to stage the newly generated audios, spectrograms, and site changes, and push them to your repository. This will automatically update your live GitHub Pages site.

# %%
# --- CONFIGURATION ---
GIT_USER_EMAIL = "your_email@example.com"
GIT_USER_NAME = "AayushPrjapati"
GIT_TOKEN = "YOUR_GITHUB_PERSONAL_ACCESS_TOKEN"  # Get from GitHub developer settings
GIT_REPO_URL = f"https://{GIT_USER_NAME}:{GIT_TOKEN}@github.com/AayushPrjapati/DPS-TSE.git"
# ---------------------

# !git config --global user.email "$GIT_USER_EMAIL"
# !git config --global user.name "$GIT_USER_NAME"

# Stage new audio and spectrogram files
# !git add docs/audio/ docs/images/

# Check status
# !git status

# Commit and push
# !git commit -m "chore: update audio samples and spectrograms from Colab run"
# !git push "$GIT_REPO_URL" main
